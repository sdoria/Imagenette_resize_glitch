# %% [markdown]
# ## Imagewoof -160

# %%
# run by @mgrankin
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 --gpu 2 \
                --opt adam
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.159516</td>
#       <td>2.506504</td>
#       <td>0.228000</td>
#       <td>0.726000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.926315</td>
#       <td>1.927992</td>
#       <td>0.318000</td>
#       <td>0.846000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.703951</td>
#       <td>1.818840</td>
#       <td>0.462000</td>
#       <td>0.906000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.502392</td>
#       <td>1.412812</td>
#       <td>0.590000</td>
#       <td>0.946000</td>
#       <td>00:17</td>
#     </tr>
# ...

# %%
# %run train.py --run 3 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 20 --lr 3e-3 --gpu 0 \
                --opt adam --full_size 0
# Out:
# lr: 0.003; eff_lr: 0.003; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /root/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.063417</td>
#       <td>2.060172</td>
#       <td>0.324000</td>
#       <td>0.798000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.948644</td>
#       <td>2.185543</td>
#       <td>0.316000</td>
#       <td>0.822000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.842947</td>
#       <td>1.910421</td>
#       <td>0.390000</td>
#       <td>0.850000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.748883</td>
#       <td>1.908268</td>
# ...

# %% [markdown]
# ## Imagewoof - full size

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 \
                --opt adam --full_size 1
# Out:
# lr: 0.003; eff_lr: 0.003; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /root/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.119217</td>
#       <td>2.217062</td>
#       <td>0.276000</td>
#       <td>0.780000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.901218</td>
#       <td>2.124912</td>
#       <td>0.322000</td>
#       <td>0.810000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.705978</td>
#       <td>1.752067</td>
#       <td>0.446000</td>
#       <td>0.878000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.502117</td>
#       <td>1.439943</td>
# ...

# %%
# %run train.py --run 3 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 20 --lr 3e-3 --gpu 0 \
                --opt adam --full_size 1
# Out:
# lr: 0.003; eff_lr: 0.003; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /root/.fastai/data/imagewoof
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.031401</td>
#       <td>2.188001</td>
#       <td>0.284000</td>
#       <td>0.754000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.919138</td>
#       <td>2.728084</td>
#       <td>0.278000</td>
#       <td>0.714000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.807541</td>
#       <td>1.992063</td>
#       <td>0.394000</td>
#       <td>0.852000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.751416</td>
#       <td>1.842543</td>
# ...
